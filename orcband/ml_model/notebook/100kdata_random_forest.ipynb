# %%
import sys
sys.path.append("../code/")
import randon_forest_optimized_model
import pandas as pd

# %%
data = pd.read_csv('C:/Users/meng1/Desktop/data_science/DCPdata100K.csv')

RFR_score = randon_forest_optimized_model.Random_Forest_Reg(data)
