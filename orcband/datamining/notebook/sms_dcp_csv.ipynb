# %% [markdown]
# First of all, we need to import some packages and sms_dcp_csv funtion

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("../code/")
import sms_dcp_csv

# %% [markdown]
# Then we have to load our raw data

# %%
data=pd.read_csv('../../../documentation/data/HCEPDB_moldata.csv')

# %% [markdown]
# Since the raw data is so big, we only select the first 100 data to compute

# %%
data2=data[0:100]

# %% [markdown]
# In the end, all we need to do is excute the sms_dcp funtion

# %%
sms_dcp_csv.sms_dcp(data2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:18<00:00,  5.34it/s]
#     e_gap_alpha         ATS0v       ATS1p       ATS2p       ATS5p      ATSC0i  \
# 0      2.022944  10271.633770   92.009479  147.786482  141.295254   61.225565
# 1      1.630750  12357.256702  123.520407  188.628325  228.864300   76.216932
# 2      1.462158  12657.383466  123.821003  198.750861  216.666453   78.267150
# 3      1.682250  10795.220714  127.485758  191.551388  137.122069   86.272146
# 4      1.809439  10481.976287   99.674812  162.749205  155.903522   51.834625
# 5      2.029717  12720.679381  116.096176  187.294221  241.169541   72.271171
# 6      2.201106   9758.332621   96.205243  158.154354  126.937426   47.397278
# 7      1.982122  10821.757202  104.461723  171.515254  171.778816   51.154511
# 8      2.331815  11699.441287  108.269265  172.932570  198.839529   61.896693
# ...
