# %% [markdown]
# First of all, let's import some packages and Data_distribution function

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("../code/")
import data_distribution

# %% [markdown]
# Then, we need to load our data into the notebook

# %%
data=pd.read_csv('../../../documentation/data/DCPdata100K.csv')

# %% [markdown]
# In the end, just execute the function by inserting data

# %%
data_distribution.datadistribution(data)
